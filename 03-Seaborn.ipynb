# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
prop = sns.load_dataset('tips')
prop
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(prop['total_bill'])

# %%
sns.distplot(prop['total_bill'], bins=30)

# %%
sns.jointplot(x='total_bill',y='tip', data = prop)

# %%
sns.jointplot(x='total_bill',y='tip', data = prop, kind ='hex')

# %%
sns.jointplot(x='total_bill',y='tip', data = prop, kind = 'reg')

# %%
sns.jointplot(x='total_bill',y='tip', data = prop, kind='kde')

# %%
sns.pairplot(prop)

# %%
sns.pairplot(prop, diag_kind= 'kde')

# %%
sns.pairplot(prop, diag_kind= 'kde', hue='sex')

# %%
sns.pairplot(prop, diag_kind= 'kde', hue = 'size')

# %%
sns.rugplot(prop['total_bill'])

# %% [markdown]
# ### Grafico para categorias

# %%
sns.barplot(x='sex',y='total_bill',data=prop)

# %%
sns.countplot(x='smoker',data=prop)

# %%
sns.boxplot(x='day',y='total_bill',hue='sex',data= prop)

# %%
sns.violinplot(x='day',y='total_bill',data= prop, hue = 'smoker',split = True, 
               palette= ['red','blue'], saturation=0.5)

# %%
sns.stripplot(x='day',y='total_bill',data= prop)

# %%
sns.stripplot(x='day',y='total_bill',data= prop, hue = 'sex')

# %%
sns.swarmplot(x='day',y='total_bill',data= prop, hue = 'sex')

# %%
sns.violinplot(x='day',y='total_bill',data= prop,palette = ['blue','red','gray','yellow'], saturation=0.5)
sns.swarmplot(x='day',y='total_bill',data= prop,palette = ['blue','red','gray','yellow'],)

# %% [markdown]
# ### Mapas de calor

# %%
vuelos = sns.load_dataset('flights')

# %%
vuelos
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
vuelos_matriz = vuelos.pivot_table(index = 'month', columns='year', values='passengers')

# %%
vuelos_matriz
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
type(vuelos_matriz)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.heatmap(vuelos_matriz)

# %%
sns.heatmap(vuelos_matriz, cmap = 'plasma') # viridis plasma inferno magma coolwarm

# %%
sns.heatmap(vuelos_matriz, linecolor='red', linewidths=0.2)

# %% [markdown]
# ### Graficos de cuadricula

# %%
flores = sns.load_dataset('iris')
flores
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(flores, hue = 'species')

# %%
g = sns.PairGrid(flores)
g.map(plt.scatter)

# %%
g = sns.PairGrid(flores, hue='species')
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
g = sns.FacetGrid(prop, col = 'time', row = 'smoker')
g.map(sns.distplot,'total_bill')

# %%
g = sns.FacetGrid(prop, col = 'time', row = 'smoker')
g.map(plt.scatter,'total_bill','tip')

# %% [markdown]
# # Graficos de Regresion

# %%
sns.lmplot(x = 'total_bill',y = 'tip',data = prop)

# %%
sns.lmplot(x = 'total_bill',y = 'tip',data = prop, hue='sex', markers=['o','x'])

# %%
sns.lmplot(x = 'total_bill',y = 'tip',data = prop, hue='sex', markers=['o','x'], scatter_kws={'s':80})

# %%
sns.set_context('notebook',font_scale=1.5)
sns.lmplot(x = 'total_bill',y = 'tip',data = prop, col = 'day', row='sex')

# %%
sns.set_context('notebook',font_scale=1.5)
sns.lmplot(x = 'total_bill',y = 'tip',data = prop, col = 'day',row = 'smoker', hue='sex',
          aspect= 0.8, size = 8)
# Out:
# D:\Documentos\Anaconda\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.lmplot(x = 'total_bill',y = 'tip',data = prop, aspect= 0.8, size = 10)
plt.show()
# Out:
# D:\Documentos\Anaconda\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Estilos y colores

# %%
sns.set_context('notebook',font_scale=1.5) # cambiar la escala de la letra
plt.figure(figsize = (10,4))            # tamano del grafico
sns.set_style('white')                  # estilo
sns.countplot(x='sex', data = prop)     
sns.despine(left = True,bottom = True)  # quitar el recuadro

# %%
sns.countplot(x='sex', data = prop, palette=['red','yellow'],saturation=0.4)
